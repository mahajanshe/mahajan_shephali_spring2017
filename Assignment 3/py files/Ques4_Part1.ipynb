# %%
#Importing all the required libraries
import pandas as pd
import numpy as np
import csv
import datetime as dt
from io import StringIO

# %%
#Converting csv into dataframe
df1=pd.read_csv('movies_awards.csv', parse_dates=[1])

# %%
#Filling zero's for NaN values
df1 = df1.fillna(value= 0)

# %%
df2 = df1[['Awards']]

# %%
df2['']
# Out:
#                                                   Awards
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                 1 win & 2 nominations.
# 4                                                 1 win.
# 5                                          1 nomination.
# 6                                3 wins & 2 nominations.
# 7                                  1 win & 1 nomination.
# 8                                                      0
# 9                                                      0
# 10                                                     0
# 11                                        5 nominations.
# 12                                                     0
# 13                               2 wins & 5 nominations.
# 14                                                     0
# ...

# %%
df1['Awards'] = df['raw'].str.extract('([A-Z]\w{0,})', expand=True)
