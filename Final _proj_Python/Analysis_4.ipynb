# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# import pandas.tools.rplot as rplot
from sklearn.ensemble import RandomForestClassifier

# %%
df1 = pd.read_csv("Crime_Report_Chicago.csv")

# %%
df1 = df1.rename(columns={'Primary Type': 'Category'})

# %%
df1.Category.value_counts()
# Out:
# THEFT                                60139
# BATTERY                              49608
# CRIMINAL DAMAGE                      30516
# ASSAULT                              18488
# OTHER OFFENSE                        16704
# DECEPTIVE PRACTICE                   16693
# BURGLARY                             14007
# NARCOTICS                            12120
# ROBBERY                              11754
# MOTOR VEHICLE THEFT                  11201
# CRIMINAL TRESPASS                     6207
# WEAPONS VIOLATION                     3373
# OFFENSE INVOLVING CHILDREN            2244
# PUBLIC PEACE VIOLATION                1589
# CRIM SEXUAL ASSAULT                   1415
# INTERFERENCE WITH PUBLIC OFFICER       918
# SEX OFFENSE                            890
# PROSTITUTION                           799
# HOMICIDE                               762
# ARSON                                  519
# LIQUOR LAW VIOLATION                   219
# KIDNAPPING                             202
# ...

# %%
df1.Category.value_counts().plot(kind = 'bar')

# %%
plt.show()

# %%
df2= df1.Block.value_counts()
df3= df2.head(10)
df3
# Out:
# 001XX N STATE ST                       799
# 0000X W TERMINAL ST                    474
# 008XX N MICHIGAN AVE                   433
# 0000X N STATE ST                       365
# 076XX S CICERO AVE                     303
# 064XX S DR MARTIN LUTHER KING JR DR    257
# 011XX S CANAL ST                       250
# 0000X S STATE ST                       242
# 006XX N MICHIGAN AVE                   221
# 038XX W ROOSEVELT RD                   214
# Name: Block, dtype: int64

# %%
fig, axs = plt.subplots(1,2)
df1[(df1.Category =='ROBBERY') ].Block.value_counts().plot(kind ='barh', ax=axs[0], title = 'Robbery')
df1[(df1.Category =='NARCOTICS')].Block.value_counts().plot(kind='bar', ax=axs[1], title = 'Narcotics', color = 'g')

# %%
plt.show()
