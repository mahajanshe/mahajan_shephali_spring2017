# %%
import csv, time
import numpy as np
from datetime import datetime
import pandas as pd
from io import StringIO

# %%
crime_2016 = pd.read_csv('Crimes_2016.csv', low_memory=False)
crime_2016.head()
# Out:
#          ID Case Number            Date                  Block  IUCR  \
# 0  10508593    HZ250410  5/3/2016 21:00     042XX W MADISON ST  1811
# 1  10508594    HZ250385  5/3/2016 21:35    065XX S KEDVALE AVE   810
# 2  10508595    HZ250362  5/3/2016 14:45      045XX S DAMEN AVE   560
# 3  10508597    HZ250202  5/3/2016 18:42  063XX S CLAREMONT AVE   486
# 4  10508598    HZ250298  5/3/2016 15:00    070XX S INDIANA AVE   320
#
#   Primary Type                   Description Location Description Arrest  \
# 0    NARCOTICS  POSS: CANNABIS 30GMS OR LESS             SIDEWALK   True
# 1        THEFT                     OVER $500            APARTMENT  False
# 2      ASSAULT                        SIMPLE               STREET  False
# 3      BATTERY       DOMESTIC BATTERY SIMPLE             SIDEWALK  False
# 4      ROBBERY         STRONGARM - NO WEAPON             SIDEWALK  False
#
#   Domestic              ...                Ward  Community Area  FBI Code  \
# ...

# %%
crime_2016['ID'].count()
# Out:
# 261004
