# %%
import os, requests, json
key= os.environ.get("api_key")

# %%
#website: https://sandbox.amadeus.com/travel-innovation-sandbox/apis/get/flights/inspiration-search

# %%
url = "http://api.sandbox.amadeus.com/v1.2/flights/extensive-search?origin=NYC&destination=LAS&departure_date=2017-07&apikey=" +key

# %%
#departure_date= 201707
page = 0

# %%
response = requests.get(url).json()
# with open(str(date) + '_article_' + str(page)+ '.json', 'w') as fp:
#     json.dump(response, fp)

# %%
with open(str(departure_date) + '_flight_' + '.json', 'w') as fp:
    json.dump(response, fp)
    page += 1
    departure_date += 1
    print(page)
# Out:
# 1

# %%
response
# Out:
# {'currency': 'USD',
#  'origin': 'NYC',
#  'results': [{'airline': 'UA',
#    'departure_date': '2017-07-03',
#    'destination': 'LAS',
#    'price': '231.40',
#    'return_date': '2017-07-09'},
#   {'airline': 'UA',
#    'departure_date': '2017-07-03',
#    'destination': 'LAS',
#    'price': '231.40',
#    'return_date': '2017-07-04'},
#   {'airline': 'UA',
#    'departure_date': '2017-07-03',
#    'destination': 'LAS',
#    'price': '231.40',
#    'return_date': '2017-07-05'},
#   {'airline': 'UA',
#    'departure_date': '2017-07-03',
#    'destination': 'LAS',
#    'price': '231.40',
#    'return_date': '2017-07-06'},
#   {'airline': 'UA',
#    'departure_date': '2017-07-03',
#    'destination': 'LAS',
#    'price': '231.40',
#    'return_date': '2017-07-07'},
#   {'airline': 'UA',
#    'departure_date': '2017-07-03',
#    'destination': 'LAS',
#    'price': '231.40',
#    'return_date': '2017-07-08'},
#   {'airline': 'UA',
#    'departure_date': '2017-07-03',
# ...
